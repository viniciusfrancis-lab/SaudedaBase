# %%
import pandas as pd

# %%
df = pd.read_parquet (r"C:\Users\vfpaula\OneDrive - SEDU\Área de Trabalho\Painel_de_Alertas\dados\EMPILHADO_MATRICULAS.parquet")

# %%
df.head().T
# Out:
#                                                                      897  \
# id_aluno                                                           42708
# nm_aluno                                               LIVIA LIMA CAMPOS
# data_nascimento                                               2009-07-08
# inep_escola                                                     32015631
# nm_escola                                  EEEM NOSSA SENHORA DE LOURDES
# nm_regional                                             SRE NOVA VENECIA
# id_ano_letivo                                                         29
# num_ano_letivo                                                      2026
# dt_matricula                                                  2026-01-01
# dt_enturmacao                                                 2026-02-02
# situacao_enturmacao                                             Em curso
# situacao_matricula                                              Em curso
# ...

# %%
print(df['data_referencia'].max())
# Out:
# 2026-05-14
